# %%
import pandas_datareader as web
import datetime
import numpy as np
import pandas as pd
from time import sleep

# %%
tickers = pd.read_csv(r'{}.csv'.format("stock_list"), engine='python')
tickers.to_csv(r'{}.csv'.format("stock_list2"))
START_YR = "2009"
YRS_MIN = 10
RAW_DIR = "data/raw"
YRS_DIR = "data/yearly"
THREE_M_DIR = "data/3_months"
FORCE_UPDATE = False
REPASS = False
STOCK_LIST_DIR = "stock_list2"
START_LIST_NUM = 0 #(500/4)
END_LIST_NUM = 0 #(500/4)*2

def set_col(df, c_name, c_type="str", tmp_i="False", v=np.nan):
    if not (c_name in df.columns):
        if c_type == "str":
            df[c_name] = ""
            df[c_name] = df[c_name].astype(str)
        else:
            df[c_name] = np.nan
    if not tmp_i == "False":
        if c_type == "str":
            try:
                df.at[tmp_i, c_name] = ""
            except:
                df[c_name] = ""
                
        df.at[tmp_i, c_name] = v
        

try:
    tickers = pd.read_csv(r'{}.csv'.format(STOCK_LIST_DIR), engine='python')
    tickers = tickers.loc[:, ~tickers.columns.str.contains('^Unnamed')]
except:
    pass
    tickers = pd.DataFrame()


set_col(tickers, 'symbol')
set_col(tickers, 'company')
set_col(tickers, 'price', "int")
set_col(tickers, 'ignore')
set_col(tickers, 'start_yr')
set_col(tickers, 'ignore_error')
set_col(tickers, 'adj_up_start_schedule')
set_col(tickers, 'adj_up_end_schedule')

if tickers.empty:
    tickers.to_csv(r'{}.csv'.format(STOCK_LIST_DIR))


for i, row in tickers.iterrows():
    if START_LIST_NUM>0 and i<START_LIST_NUM:
        continue
    if END_LIST_NUM>0 and END_LIST_NUM>START_LIST_NUM and i>END_LIST_NUM:
        break
    SYMBOL = row["symbol"]
#     SYMBOL = "PG"
    
    try:        
        current_stock = pd.read_csv(r'{}/{}_{}.csv'.format(RAW_DIR, SYMBOL, "history"), index_col=['Date'] , parse_dates=['Date'])
        tickers.at[i, "ignore"] = False
    except:
        current_stock = ""
        
    print(i+1, SYMBOL)
    if (pd.notnull(row['ignore']) and row['ignore'] and not REPASS):
        print("--Ignore: {}".format(row['ignore'] and not REPASS))
        continue
    if FORCE_UPDATE or not str(current_stock):
        print("--get data")
        try:
#             sleep(15)
            current_stock = web.DataReader(SYMBOL, data_source="yahoo", start=START_YR) 
            set_col(tickers, "ignore","str", i, False)
        except Exception as e:
            set_col(tickers, "ignore","str", i, True)
            set_col(tickers, "ignore_error","str", i, e)
            print("---Error: {}".format(e))
            tickers.to_csv(r'{}.csv'.format(STOCK_LIST_DIR))
            continue
    
        
#     for three months 70-75
    tickers.at[i, "price"] = current_stock.tail(1)["Close"][0]
    tickers.at[i, "ignore"] = skip = current_stock.tail(1).index[0].year-current_stock.head(1).index[0].year < YRS_MIN
    tickers.at[i, "start_yr"] = current_stock.head(1).index[0].year
    print("--Skip: {}".format(skip))
    if skip:
        current_stock.to_csv(r'{}/{}_{}.csv'.format("data/under_min", current_stock.head(1).index[0].year, SYMBOL))
        tickers.to_csv(r'{}.csv'.format(STOCK_LIST_DIR))
        continue
    else:
        current_stock.to_csv(r'{}/{}_{}.csv'.format(RAW_DIR, SYMBOL, "history"))

    yearly_adj_df = pd.DataFrame()
    yearly_df = pd.DataFrame()
    three_m_adj_df = pd.DataFrame()
    three_m_c_df = pd.DataFrame()
    three_m_pc_df = pd.DataFrame()
    for j, row2 in current_stock.iterrows():
        yearly_adj_df.at["{:02d}-{:02d}".format(j.month, j.day), j.year] = row2["Adj Close"]
        yearly_df.at["{:02d}-{:02d}".format(j.month, j.day), j.year] = row2["Close"]
  
    yearly_adj_df.sort_index(inplace=True)
    yearly_df.sort_index(inplace=True)
    for j, row2 in yearly_df.iterrows():
        adj_d_ups = 0
        adj_d_downs = 0
        c_d_ups = 0
        c_d_downs = 0
        for yr in yearly_df.columns:
            d = pd.to_datetime('{}-{}'.format(yr, j), format="%Y-%m-%d", dayfirst=True, errors='coerce')
            three_m_adj_df.at[j, yr] = 0
            three_m_c_df.at[j, yr] = 0
            three_m_pc_df.at[j, yr] = 0
            if not pd.isnull(d):
                f = d + datetime.timedelta(days=75)
                tmp_three_m_df = current_stock.loc['{}-{:02d}-{:02d}'.format(d.year, d.month, d.day):'{}-{:02d}-{:02d}'.format(f.year, f.month, f.day)]
                
                if not tmp_three_m_df.empty:
                    adj_first_3m_num = tmp_three_m_df.head(3)["Adj Close"].dropna().head(1)[0]
                    c_first_3m_num = tmp_three_m_df.head(3)["Close"].dropna().head(1)[0]              
                    adj_last_3m_num = tmp_three_m_df.tail(3)["Adj Close"].dropna().head(1)[0]
                    c_last_3m_num = tmp_three_m_df.tail(3)["Close"].dropna().head(1)[0]
                    
                    three_m_adj_df.at[j, yr] = adj_last_3m_num - adj_first_3m_num
                    three_m_c_df.at[j, yr] = c_last_3m_num - c_first_3m_num
                    three_m_pc_df.at[j, yr] = ((c_last_3m_num - c_first_3m_num)/c_last_3m_num)*100
                    if (adj_last_3m_num - adj_first_3m_num)>0:
                        adj_d_ups=adj_d_ups+1
                    else:
                        adj_d_downs=adj_d_downs+1

                    if (c_last_3m_num - c_first_3m_num)>0:
                        c_d_ups=c_d_ups+1
                    else:
                        c_d_downs=c_d_downs+1

                
        set_col(three_m_adj_df, "ups", "int", j, adj_d_ups)
        set_col(three_m_c_df, "ups", "int", j, c_d_ups)
        set_col(three_m_pc_df, "ups", "int", j, c_d_ups)
        set_col(tickers, "adj_ups", "int", i, adj_d_ups)
        set_col(tickers, "close_ups", "int", i, c_d_ups)
        set_col(three_m_adj_df, "downs", "int", j, adj_d_downs)
        set_col(three_m_c_df, "downs", "int", j, c_d_downs)
        set_col(three_m_pc_df, "downs", "int", j, c_d_downs)
        set_col(tickers, "adj_downs", "int", i, adj_d_downs)
        set_col(tickers, "close_downs", "int", i, c_d_downs)
        set_col(three_m_adj_df, "end_day_sum","str", j, '{:02d}-{:02d}'.format(f.month, f.day))
        set_col(three_m_c_df, "end_day_sum","str", j, '{:02d}-{:02d}'.format(f.month, f.day))
        
    three_m_adj_df['avg'] = three_m_adj_df.loc[:, ~three_m_adj_df.columns.str.contains('^ups|^downs|^avg|^end_day_sum', na=False)].mean(axis=1)
    three_m_c_df['avg'] = three_m_c_df.loc[:, ~three_m_c_df.columns.str.contains('^ups|^downs|^avg|^end_day_sum', na=False)].mean(axis=1)
    three_m_pc_df['avg'] = three_m_pc_df.loc[:, ~three_m_pc_df.columns.str.contains('^ups|^downs|^avg|^end_day_sum', na=False)].mean(axis=1)

    yearly_adj_df.to_csv(r'{}/{}_yrs_adj_data.csv'.format(YRS_DIR, SYMBOL))
    yearly_df.to_csv(r'{}/{}_yrs_close_data.csv'.format(YRS_DIR, SYMBOL))
    three_m_adj_df.sort_index(inplace=True)
    three_m_adj_df.to_csv(r'{}/{}_3m_adj_data.csv'.format(THREE_M_DIR, SYMBOL))
    three_m_c_df.sort_index(inplace=True)
    three_m_c_df.to_csv(r'{}/{}_3m_c_data.csv'.format(THREE_M_DIR, SYMBOL))
    three_m_pc_df.sort_index(inplace=True)
    three_m_pc_df.to_csv(r'{}/{}_3m_pc_data.csv'.format(THREE_M_DIR, SYMBOL))
    
    set_col(tickers, "adj_up_start_schedule","str", i, three_m_adj_df.sort_values(['ups', 'avg'], ascending=[False, False]).head(1).index[0])
    set_col(tickers, "adj_up_end_schedule","str", i, three_m_adj_df.sort_values(['ups', 'avg'], ascending=[False, False]).head(1)["end_day_sum"][0])
    set_col(tickers, "close_up_start_schedule","str", i, three_m_c_df.sort_values(['ups', 'avg'], ascending=[False, False]).head(1).index[0])
    set_col(tickers, "close_up_end_schedule","str", i, three_m_c_df.sort_values(['ups', 'avg'], ascending=[False, False]).head(1)["end_day_sum"][0])
    set_col(tickers, "close_up_percent_avg","int", i, three_m_pc_df.sort_values(['ups', 'avg'], ascending=[False, False]).head(1)["avg"][0])

    tickers.to_csv(r'{}.csv'.format(STOCK_LIST_DIR))
print("Done")
# Out:
# 126 HELOF
# --get data
# --Skip: True
# 127 WINSF
# --get data
# --Skip: True
# 128 WIPKF
# --get data
# --Skip: True
# 129 WGO
# --get data
# --Skip: False
# 130 WNMLA
# --get data
# --Skip: False
# 131 WINA
# --get data
# --Skip: False
# 132 WELX
# --get data
# --Skip: False
# 133 WINH
# --get data
# --Skip: True
# 134 WING
# --get data
# --Skip: True
# 135 WTHEF
# --get data
# ---Error: No data fetched for symbol WTHEF using YahooDailyReader
# 136 WONCF
# --get data
# ---Error: No data fetched for symbol WONCF using YahooDailyReader
# 137 WINT
# --get data
# --Skip: False
# 138 WINMQ
# --get data
# --Skip: False
# 139 WRLC
# --get data
# --Skip: True
# 140 WGEI
# --get data
# --Skip: True
# 141 WINKF
# --get data
# --Skip: True
# 142 WWPW
# --get data
# --Skip: False
# 143 WMGEF
# --get data
# --Skip: True
# 144 WNCH
# --get data
# ---Error: No data fetched for symbol WNCH using YahooDailyReader
# 145 WCHS
# --get data
# --Skip: True
# 146 WCHEF
# --get data
# --Skip: True
# 147 WNCNF
# --get data
# ---Error: No data fetched for symbol WNCNF using YahooDailyReader
# 148 WBEMF
# --get data
# ---Error: 'Date'
# 149 WIMI
# --get data
# --Skip: True
# 150 WMXCF
# --get data
# --Skip: True
# 151 WLTNF
# --get data
# --Skip: True
# 152 WCRE
# --get data
# ---Error: No data fetched for symbol WCRE using YahooDailyReader
# 153 WBYLF
# --get data
# ---Error: No data fetched for symbol WBYLF using YahooDailyReader
# 154 WBHC
# --get data
# --Skip: True
# 155 WLSE
# --get data
# ---Error: 'Date'
# 156 WIBC
# --get data
# ---Error: 'Date'
# 157 WMGTF
# --get data
# --Skip: True
# 158 WLMIY
# --get data
# --Skip: False
# 159 WLMIF
# --get data
# --Skip: False
# 160 WSC
# --get data
# --Skip: True
# 161 CANSF
# --get data
# --Skip: True
# 162 WHCA
# --get data
# --Skip: True
# 163 WLTW
# --get data
# --Skip: False
# 164 WLFC
# --get data
# --Skip: False
# 165 WSM
# --get data
# --Skip: False
# 166 WPZ
# --get data
# --Skip: True
# 167 WMSI
# --get data
# --Skip: False
# 168 WLMS
# --get data
# --Skip: True
# 169 WMGPF
# --get data
# --Skip: True
# 170 WPRXF
# --get data
# ---Error: No data fetched for symbol WPRXF using YahooDailyReader
# 171 WMB
# --get data
# --Skip: False
# 172 WMCB
# --get data
# --Skip: False
# 173 WMPN
# --get data
# --Skip: False
# 174 WLH
# --get data
# ---Error: No data fetched for symbol WLH using YahooDailyReader
# 175 WIMHY
# --get data
# --Skip: True
# 176 WIMHF
# --get data
# --Skip: False
# 177 SADL
# --get data
# --Skip: False
# 178 WLDN
# --get data
# --Skip: False
# 179 WGRP
# --get data
# --Skip: True
# 180 WVVI
# --get data
# --Skip: False
# 181 WHLM
# --get data
# --Skip: False
# 182 WLLSF
# --get data
# --Skip: True
# 183 WLHSF
# --get data
# ---Error: No data fetched for symbol WLHSF using YahooDailyReader
# 184 WLXMF
# --get data
# ---Error: No data fetched for symbol WLXMF using YahooDailyReader
# 185 HWTHF
# --get data
# --Skip: False
# 186 WRD
# --get data
# --Skip: True
# 187 WLDFF
# --get data
# --Skip: True
# 188 WDCTF
# --get data
# ---Error: No data fetched for symbol WDCTF using YahooDailyReader
# 189 DMQHF
# --get data
# ---Error: No data fetched for symbol DMQHF using YahooDailyReader
# 190 WLDBF
# --get data
# --Skip: True
# 191 WBRE
# --get data
# --Skip: True
# 192 WSFT
# --get data
# --Skip: True
# 193 WIHLY
# --get data
# --Skip: True
# 194 WBRBY
# --get data
# --Skip: False
# 195 WBRBF
# --get data
# --Skip: True
# 196 WYY
# --get data
# --Skip: False
# 197 WOW
# --get data
# --Skip: True
# 198 ISEYF
# --get data
# --Skip: True
# 199 WGLD
# --get data
# ---Error: No data fetched for symbol WGLD using YahooDailyReader
# 200 WFM
# --get data
# ---Error: 'Date'
# 201 FREE
# --get data
# --Skip: True
# 202 WHZT
# --get data
# --Skip: True
# 203 WHXT
# --get data
# ---Error: No data fetched for symbol WHXT using YahooDailyReader
# 204 WLL
# --get data
# --Skip: False
# 205 WSR
# --get data
# --Skip: False
# 206 WHF
# --get data
# --Skip: True
# 207 WHITF
# --get data
# --Skip: False
# 208 SPGYF
# --get data
# --Skip: False
# 209 WRMCF
# --get data
# --Skip: True
# 210 WRIV
# --get data
# --Skip: True
# 211 WTM
# --get data
# --Skip: False
# 212 TNMLF
# --get data
# --Skip: True
# 213 WLAB
# --get data
# --Skip: False
# 214 WHGOF
# --get data
# --Skip: True
# 215 WECFY
# --get data
# ---Error: No data fetched for symbol WECFY using YahooDailyReader
# 216 WECFF
# --get data
# --Skip: False
# 217 WTBDY
# --get data
# --Skip: True
# 218 WTBCF
# --get data
# --Skip: True
# 219 WGXLF
# --get data
# ---Error: No data fetched for symbol WGXLF using YahooDailyReader
# 220 WSBHF
# --get data
# ---Error: No data fetched for symbol WSBHF using YahooDailyReader
# 221 WHSPF
# --get data
# --Skip: True
# 222 WHR
# --get data
# --Skip: False
# 223 TVTV
# --get data
# --Skip: True
# 224 WFCF
# --get data
# --Skip: False
# 225 WHLKY
# --get data
# --Skip: False
# 226 WHLKF
# --get data
# --Skip: False
# 227 WHLR
# --get data
# --Skip: True
# 228 WPM
# --get data
# --Skip: False
# 229 WRFRF
# --get data
# --Skip: True
# 230 WHTPF
# --get data
# --Skip: True
# 231 WHGRF
# --get data
# --Skip: True
# 232 WHGLY
# --get data
# --Skip: True
# 233 WGL
# --get data
# --Skip: True
# 234 WY
# --get data
# --Skip: False
# 235 WEYS
# --get data
# --Skip: False
# 236 WEX
# --get data
# --Skip: False
# 237 WEWA
# --get data
# --Skip: True
# 238 WETG
# --get data
# --Skip: True
# 239 WETH
# --get data
# --Skip: True
# 240 JDWPY
# --get data
# --Skip: True
# 241 JDWPF
# --get data
# --Skip: True
# 242 WHG
# --get data
# --Skip: False
# 243 WWR
# --get data
# --Skip: False
# 244 WTSHF
# --get data
# --Skip: False
# 245 WRK
# --get data
# --Skip: True
# 246 WSTTF
# --get data
# --Skip: True
# 247 WPRT
# --get data
# --Skip: False
# 248 WPTH
# --get data
# ---Error: 'Date'
# 249 WEBNF
# --get data
# --Skip: False
# 250 WBK
# --get data
# --Skip: False
# 251 WMTN
# --Skip: False
# Done

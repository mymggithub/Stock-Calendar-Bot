# %%
import pandas_datareader as web
import datetime
import os
import numpy as np
import pandas as pd
from time import sleep

# %%
BOT_MAX = 5
BOT_NUM = 5
START_YR = "2009"
YRS_MIN = 10
RAW_DIR = "data/raw"
YRS_DIR = "data/yearly"
FORCE_UPDATE = False
REPASS = False
STOCK_LIST_DIR = "stock_list"

if BOT_NUM>1:
#     tickers = pd.read_csv(r'{}.csv'.format(STOCK_LIST_DIR), engine='python')
#     tickers.to_csv(r'{}{}.csv'.format(STOCK_LIST_DIR, BOT_NUM))
    STOCK_LIST_DIR = "stock_list{}".format(BOT_NUM)

def set_col(df, c_name, c_type="str", tmp_i="False", v=np.nan):
    if not (c_name in df.columns):
        if c_type == "str":
            df[c_name] = ""
            df[c_name] = df[c_name].astype(str)
        else:
            df[c_name] = np.nan
    if not tmp_i == "False":
        if c_type == "str":
            try:
                df.at[tmp_i, c_name] = ""
            except:
                df[c_name] = ""
                
        df.at[tmp_i, c_name] = v
        

try:
    tickers = pd.read_csv(r'{}.csv'.format(STOCK_LIST_DIR), engine='python')
    tickers = tickers.loc[:, ~tickers.columns.str.contains('^Unnamed')]
except:
    pass
    tickers = pd.DataFrame()
    
t_len = 0
t_len_fixed = 0
START_LIST_NUM = 0
END_LIST_NUM = 0
if BOT_MAX > 0:
    t_len = len(tickers.index)
    t_len_fixed = t_len+[n for n in list(range(BOT_MAX)) if (t_len+n)%BOT_MAX==0][0]
    START_LIST_NUM = int((t_len_fixed/BOT_MAX)*(BOT_NUM-1))
    if BOT_MAX != BOT_NUM:
        END_LIST_NUM = int((t_len_fixed/BOT_MAX)*BOT_NUM)
START_LIST_NUM = 2737
print("Num:{} Start/Stop {}/{}".format(t_len, START_LIST_NUM+1, END_LIST_NUM+1 if END_LIST_NUM>0 else t_len_fixed))
        
set_col(tickers, 'symbol')
set_col(tickers, 'company')
set_col(tickers, 'price', "int")
set_col(tickers, 'ignore')
set_col(tickers, 'start_yr')
set_col(tickers, 'ignore_error')
# set_col(tickers, 'adj_up_start_schedule')
# set_col(tickers, 'adj_up_end_schedule')

if tickers.empty:
    tickers.to_csv(r'{}.csv'.format(STOCK_LIST_DIR))


for i, row in tickers.iterrows():
    if START_LIST_NUM>0 and i<START_LIST_NUM:
        continue
    if END_LIST_NUM>0 and END_LIST_NUM>START_LIST_NUM and i>END_LIST_NUM:
        break
    SYMBOL = row["symbol"]
#     SYMBOL = "PG"
    
    try:        
        current_stock = pd.read_csv(r'{}/{}_{}.csv'.format(RAW_DIR, SYMBOL, "history"), index_col=['Date'] , parse_dates=['Date'])
        tickers.at[i, "ignore"] = False
    except:
        current_stock = ""
        
    print(i+1, SYMBOL)
    if (pd.notnull(row['ignore']) and row['ignore'] and not REPASS):
        print("--Ignore: {}".format(row['ignore'] and not REPASS))
        continue
    if FORCE_UPDATE or not str(current_stock):
        print("--get data")
        try:
#             sleep(15)
            current_stock = web.DataReader(SYMBOL, data_source="yahoo", start=START_YR) 
            set_col(tickers, "ignore","str", i, False)
        except Exception as e:
            set_col(tickers, "ignore","str", i, True)
            set_col(tickers, "ignore_error","str", i, e)
            print("---Error: {}".format(e))
            tickers.to_csv(r'{}.csv'.format(STOCK_LIST_DIR))
            continue
    
        

    tickers.at[i, "price"] = current_stock.tail(1)["Close"][0]
    tickers.at[i, "ignore"] = skip = current_stock.tail(1).index[0].year-current_stock.head(1).index[0].year < YRS_MIN
    tickers.at[i, "start_yr"] = current_stock.head(1).index[0].year
    print("--Skip: {}".format(skip))
    if skip:
        current_stock.to_csv(r'{}/{}_{}.csv'.format("data/under_min", current_stock.head(1).index[0].year, SYMBOL))
        tickers.to_csv(r'{}.csv'.format(STOCK_LIST_DIR))
        continue
    else:
        if REPASS or not os.path.exists(r'{}/{}_{}.csv'.format(RAW_DIR, SYMBOL, "history")):
            current_stock.to_csv(r'{}/{}_{}.csv'.format(RAW_DIR, SYMBOL, "history"))

    if REPASS or not os.path.exists(r'{}/{}_yrs_adj_data.csv'.format(YRS_DIR, SYMBOL)) or not os.path.exists(r'{}/{}_yrs_close_data.csv'.format(YRS_DIR, SYMBOL)):
        yearly_adj_df = pd.DataFrame()
        yearly_df = pd.DataFrame()
        for j, row2 in current_stock.iterrows():
            yearly_adj_df.at["{:02d}-{:02d}".format(j.month, j.day), j.year] = row2["Adj Close"]
            yearly_df.at["{:02d}-{:02d}".format(j.month, j.day), j.year] = row2["Close"]

        yearly_adj_df.sort_index(inplace=True)
        yearly_df.sort_index(inplace=True)
    else:
        yearly_adj_df = pd.read_csv(r'{}/{}_yrs_adj_data.csv'.format(YRS_DIR, SYMBOL), parse_dates=True, index_col=['Unnamed: 0'], engine='python')
        yearly_df = pd.read_csv(r'{}/{}_yrs_close_data.csv'.format(YRS_DIR, SYMBOL), parse_dates=True, index_col=['Unnamed: 0'], engine='python')
        
    r_adj_df_list = {}
    r_c_df_list = {}
    r_pc_df_list = {}
    d_range = list(range(61))[0::15][1:][::-1]
    for r in d_range:
        r_adj_df_list[r] = pd.DataFrame()
        r_c_df_list[r] = pd.DataFrame()
        r_pc_df_list[r] = pd.DataFrame()
        for j, row2 in yearly_df.iterrows():
            adj_d_ups = adj_d_downs = c_d_ups = c_d_downs = 0
            for yr in yearly_df.columns:
                d = pd.to_datetime('{}-{}'.format(yr, j), format="%Y-%m-%d", dayfirst=True, errors='coerce')
                r_adj_df_list[r].at[j, yr] = r_c_df_list[r].at[j, yr] = r_pc_df_list[r].at[j, yr] = 0
                if not pd.isnull(d):
                    f = d + datetime.timedelta(days=r)
                    tmp_r_df = current_stock.loc['{}-{:02d}-{:02d}'.format(d.year, d.month, d.day):'{}-{:02d}-{:02d}'.format(f.year, f.month, f.day)]

                    if not tmp_r_df.empty:
                        adj_first_range_num = tmp_r_df.head(3)["Adj Close"].dropna().head(1)[0]
                        c_first_range_num = tmp_r_df.head(3)["Close"].dropna().head(1)[0]              
                        adj_last_range_num = tmp_r_df.tail(3)["Adj Close"].dropna().head(1)[0]
                        c_last_range_num = tmp_r_df.tail(3)["Close"].dropna().head(1)[0]

                        r_adj_df_list[r].at[j, yr] = adj_last_range_num - adj_first_range_num
                        r_c_df_list[r].at[j, yr] = c_last_range_num - c_first_range_num
                        r_pc_df_list[r].at[j, yr] = ((c_last_range_num - c_first_range_num)/c_last_range_num)*100
                        if (adj_last_range_num - adj_first_range_num)>0:
                            adj_d_ups=adj_d_ups+1
                        else:
                            adj_d_downs=adj_d_downs+1

                        if (c_last_range_num - c_first_range_num)>0:
                            c_d_ups=c_d_ups+1
                        else:
                            c_d_downs=c_d_downs+1
                            
            set_col(r_adj_df_list[r], "ups", "int", j, adj_d_ups)
            set_col(r_c_df_list[r], "ups", "int", j, c_d_ups)
            set_col(r_pc_df_list[r], "ups", "int", j, c_d_ups)
            set_col(r_adj_df_list[r], "downs", "int", j, adj_d_downs)
            set_col(r_c_df_list[r], "downs", "int", j, c_d_downs)
            set_col(r_pc_df_list[r], "downs", "int", j, c_d_downs)
            
            set_col(tickers, 'adj_up_start_schedule_r_{}'.format(r))
            set_col(tickers, 'adj_up_end_schedule_r_{}'.format(r))
            set_col(tickers, "adj_ups_r_{}".format(r), "int", i, adj_d_ups)
            set_col(tickers, "adj_downs_r_{}".format(r), "int", i, adj_d_downs)
            set_col(tickers, "close_ups_r_{}".format(r), "int", i, c_d_ups)
            set_col(tickers, "close_downs_r_{}".format(r), "int", i, c_d_downs)
            set_col(tickers, "close_downs_r_{}".format(r), "int", i, c_d_downs)
            
            set_col(r_adj_df_list[r], "end_day_sum","str", j, '{:02d}-{:02d}'.format(f.month, f.day))
            set_col(r_c_df_list[r], "end_day_sum","str", j, '{:02d}-{:02d}'.format(f.month, f.day))
        
        r_adj_df_list[r]['avg'] = r_adj_df_list[r].loc[:, ~r_adj_df_list[r].columns.str.contains('^ups|^downs|^avg|^end_day_sum', na=False)].mean(axis=1)
        r_c_df_list[r]['avg'] = r_c_df_list[r].loc[:, ~r_c_df_list[r].columns.str.contains('^ups|^downs|^avg|^end_day_sum', na=False)].mean(axis=1)
        r_pc_df_list[r]['avg'] = r_pc_df_list[r].loc[:, ~r_pc_df_list[r].columns.str.contains('^ups|^downs|^avg|^end_day_sum', na=False)].mean(axis=1)

        range_dir = "data/r_{}".format(r)
        r_adj_dir = r'{}/{}_r{}_adj_data.csv'.format(range_dir, SYMBOL, r)
        r_c_dir = r'{}/{}_r{}_c_data.csv'.format(range_dir, SYMBOL, r)
        r_pc_dir = r'{}/{}_r{}_pc_data.csv'.format(range_dir, SYMBOL, r)
        if not os.path.exists(range_dir):
            os.mkdir(range_dir)
        r_adj_df_list[r].sort_index(inplace=True)
        r_adj_df_list[r].to_csv(r_adj_dir)
        r_c_df_list[r].sort_index(inplace=True)
        r_c_df_list[r].to_csv(r_c_dir)
        r_pc_df_list[r].sort_index(inplace=True)
        r_pc_df_list[r].to_csv(r_pc_dir)

        set_col(tickers, "adj_up_start_schedule_r_{}".format(r),"str", i, r_adj_df_list[r].sort_values(['ups', 'avg'], ascending=[False, False]).head(1).index[0])
        set_col(tickers, "adj_up_end_schedule_r_{}".format(r),"str", i, r_adj_df_list[r].sort_values(['ups', 'avg'], ascending=[False, False]).head(1)["end_day_sum"][0])
        set_col(tickers, "close_up_start_schedule_r_{}".format(r),"str", i, r_c_df_list[r].sort_values(['ups', 'avg'], ascending=[False, False]).head(1).index[0])
        set_col(tickers, "close_up_end_schedule_r_{}".format(r),"str", i, r_c_df_list[r].sort_values(['ups', 'avg'], ascending=[False, False]).head(1)["end_day_sum"][0])
        set_col(tickers, "close_up_percent_avg_r_{}".format(r),"int", i, r_pc_df_list[r].sort_values(['ups', 'avg'], ascending=[False, False]).head(1)["avg"][0])
    
    if REPASS or not os.path.exists(r'{}/{}_yrs_adj_data.csv'.format(YRS_DIR, SYMBOL)):
        yearly_adj_df.to_csv(r'{}/{}_yrs_adj_data.csv'.format(YRS_DIR, SYMBOL))
    if REPASS or not os.path.exists(r'{}/{}_yrs_close_data.csv'.format(YRS_DIR, SYMBOL)):
        yearly_df.to_csv(r'{}/{}_yrs_close_data.csv'.format(YRS_DIR, SYMBOL))
    tickers.to_csv(r'{}.csv'.format(STOCK_LIST_DIR))
print("Done")
# Out:
# Num:2987 Start/Stop 2738/2990
# 2738 TTDKY
# --Skip: False
# 2739 AMTD
# --Skip: False
# 2740 TSI
# --Skip: False
# 2741 TCLHF
# --Skip: False
# 2742 TCF
# --Skip: False
# 2743 TCP
# --Skip: False
# 2744 TRP
# --Skip: False
# 2745 TDLAF
# --Skip: False
# 2746 TWODF
# --Skip: False
# 2747 TAYD
# --Skip: False
# 2748 TTCM
# --Skip: False
# 2749 TCO
# --Skip: False
# 2750 OAOFY
# --Skip: False
# 2751 TATYY
# --Skip: False
# 2752 TATYF
# --Skip: False
# 2753 TATLY
# --Skip: False
# 2754 TTM
# --Skip: False
# 2755 TATT
# --Skip: False
# 2756 TSLLF
# --Skip: False
# 2757 TGB
# --Skip: False
# 2758 TARO
# --Skip: False
# 2759 TGT
# --Skip: False
# 2760 TRGP
# --Skip: False
# 2761 TNREF
# --Skip: False
# 2762 TAPM
# --Skip: False
# 2763 TPR
# --Skip: False
# 2764 TAPOF
# --Skip: False
# 2765 TAOP
# --Skip: False
# 2766 TRX
# --Skip: False
# 2767 SKT
# --Skip: False
# 2768 TNEYF
# --Skip: False
# 2769 TALN
# --Skip: False
# 2770 TAL
# --Skip: False
# 2771 TAKUF
# --Skip: False
# 2772 TAK
# --Skip: False
# 2773 TKPHF
# --Skip: False
# 2774 TTWO
# --Skip: False
# 2775 TYOYY
# --Skip: False
# 2776 TSM
# --Skip: False
# 2777 TWN
# --Skip: False
# 2778 TAIT
# --Skip: False
# 2779 TLRDQ
# --Skip: False
# 2780 THYCY
# --Skip: False
# 2781 TAOIF
# --Skip: False
# 2782 TBTC
# --Skip: False
# 2783 TACBY
# --Skip: False
# 2784 TABCF
# --Skip: False
# 2785 TROW
# --Skip: False
# 2786 TMUS
# --Skip: False
# 2787 THLM
# --Skip: False
# 2788 RHP
# --Skip: False
# 2789 R
# --Skip: False
# 2790 RYAAY
# --Skip: False
# 2791 RWEOY
# --Skip: False
# 2792 RUTH
# --Skip: False
# 2793 RUSMF
# --Skip: False
# 2794 RMLFF
# --Skip: False
# 2795 RUSHB
# --Skip: False
# 2796 RUSHA
# --Skip: False
# 2797 RBCN
# --Skip: False
# 2798 RTWIQ
# --Skip: False
# 2799 RPT
# --Skip: False
# 2800 RPM
# --Skip: False
# 2801 RES
# --Skip: False
# 2802 RVT
# --Skip: False
# 2803 RMT
# --Skip: False
# 2804 ROYL
# --Skip: False
# 2805 RYSMF
# --Skip: False
# 2806 RYLPF
# --Skip: False
# 2807 PHG
# --Skip: False
# 2808 RGLD
# --Skip: False
# 2809 RYFL
# --Skip: False
# 2810 RYDAF
# --Skip: False
# 2811 RCL
# --Skip: False
# 2812 RY
# --Skip: False
# 2813 ROSYY
# --Skip: False
# 2814 ROST
# --Skip: False
# 2815 RST
# --Skip: False
# 2816 RIHC
# --Skip: False
# 2817 ROP
# --Skip: False
# 2818 RTNB
# --Skip: False
# 2819 RSAU
# --Skip: False
# 2820 RMIOF
# --Skip: False
# 2821 RYCEY
# --Skip: False
# 2822 RYCEF
# --Skip: False
# 2823 ROL
# --Skip: False
# 2824 ROHCY
# --Skip: False
# 2825 GCRIF
# --Skip: False
# 2826 RSGUF
# --Skip: False
# 2827 ROG
# --Skip: False
# 2828 RCI
# --Skip: False
# 2829 RCKXF
# --Skip: False
# 2830 RMCF
# --Skip: False
# 2831 RCKY
# --Skip: False
# 2832 RMTI
# --Skip: False
# 2833 ROK
# --Skip: False
# 2834 RCKHF
# --Skip: False
# 2835 ROFO
# --Skip: False
# 2836 RKFL
# --Skip: False
# 2837 RCKTF
# --Skip: False
# 2838 RRRI
# --Skip: False
# 2839 RHHVF
# --Skip: False
# 2840 RHHBY
# --Skip: False
# 2841 RBSY
# --Skip: False
# 2842 ROBOF
# --Skip: False
# 2843 RHI
# --Skip: False
# 2844 RRTS
# --Skip: False
# 2845 RKGXF
# --Skip: False
# 2846 RMRM
# --Skip: False
# 2847 RLI
# --Skip: False
# 2848 RIVE
# --Skip: False
# 2849 RVSB
# --Skip: False
# 2850 RVSDF
# --Skip: False
# 2851 RCBC
# --Skip: False
# 2852 RAD
# --Skip: False
# 2853 RBA
# --Skip: False
# 2854 RITT
# --Skip: False
# 2855 RITPF
# --Skip: False
# 2856 RIOCF
# --Skip: False
# 2857 RTPPF
# --Skip: False
# 2858 RIO
# --Skip: False
# 2859 RTNTF
# --Skip: False
# 2860 RYOOF
# --Skip: False
# 2861 RINO
# --Skip: False
# 2862 REI
# --Skip: False
# 2863 RNET
# --Skip: False
# 2864 RTMVF
# --Skip: False
# 2865 RIGL
# --Skip: False
# 2866 RICOY
# --Skip: False
# 2867 RELL
# --Skip: False
# 2868 RPKIF
# --Skip: False
# 2869 RIBT
# --Skip: False
# 2870 RBBN
# --Skip: False
# 2871 RHNO
# --Skip: False
# 2872 RGCO
# --Skip: False
# 2873 STHI
# --Skip: False
# 2874 RFIL
# --Skip: False
# 2875 REXN
# --Skip: False
# 2876 REX
# --Skip: False
# 2877 RVLT
# --Skip: False
# 2878 RSLS
# --Skip: False
# 2879 RSSS
# --Skip: False
# 2880 REFR
# --Skip: False
# 2881 RSG
# --Skip: False
# 2882 FRBK
# --Skip: False
# 2883 RBCAA
# --Skip: False
# 2884 REPYY
# --Skip: False
# 2885 REPYF
# --Skip: False
# 2886 KRMD
# --Skip: False
# 2887 RGEN
# --Skip: False
# 2888 REPCF
# --Skip: False
# 2889 REOP
# --Skip: False
# 2890 GDYMF
# --Skip: False
# 2891 RTOKY
# --Skip: False
# 2892 RKLIF
# --Skip: False
# 2893 RCII
# --Skip: False
# 2894 RNVT
# --Skip: False
# 2895 RCAR
# --Skip: False
# 2896 RNVA
# --Skip: False
# 2897 RCG
# --Skip: False
# 2898 RNWF
# --Skip: False
# 2899 RNUGF
# --Skip: False
# 2900 SOL
# --Skip: False
# 2901 RNECY
# --Skip: False
# 2902 RNECF
# --Skip: False
# 2903 RNST
# --Skip: False
# 2904 RNR
# --Skip: False
# 2905 REMYF
# --Skip: False
# 2906 REMI
# --Skip: False
# 2907 MARK
# --Skip: False
# 2908 RLXXF
# --Skip: False
# 2909 RELX
# --Skip: False
# 2910 RELV
# --Skip: False
# 2911 RQHTF
# --Skip: False
# 2912 RS
# --Skip: False
# 2913 RLBY
# --Skip: False
# 2914 RTMAF
# --Skip: False
# 2915 RGA
# --Skip: False
# 2916 RPMT
# --Skip: False
# 2917 RGS
# --Skip: False
# 2918 RF
# --Skip: False
# 2919 RGBD
# --Skip: False
# 2920 RGUS
# --Skip: False
# 2921 RPGLF
# --Skip: False
# 2922 RGIN
# --Skip: False
# 2923 RGRX
# --Skip: False
# 2924 REGN
# --Skip: False
# 2925 REG
# --Skip: False
# 2926 RAFI
# --Skip: False
# 2927 RGBOQ
# --Skip: False
# 2928 RBC
# --Skip: False
# 2929 RFCS
# --Skip: False
# 2930 RSCF
# --Skip: False
# 2931 RLTR
# --Skip: False
# 2932 RCIT
# --Skip: False
# 2933 REED
# --Skip: False
# 2934 RWT
# --Skip: False
# 2935 REDW
# --Skip: False
# 2936 RWCB
# --Skip: False
# 2937 REDFY
# --Skip: False
# 2938 RFLXF
# --Skip: False
# 2939 RRGB
# --Skip: False
# 2940 RDEXF
# --Skip: False
# 2941 RMES
# --Skip: False
# 2942 RLH
# --Skip: False
# 2943 RDEIY
# --Skip: False
# 2944 RDEIF
# --Skip: False
# 2945 RCDTF
# --Skip: False
# 2946 RCON
# --Skip: False
# 2947 RBGPF
# --Skip: False
# 2948 RBGLY
# --Skip: False
# 2949 RNWEF
# --Skip: False
# 2950 UTG
# --Skip: False
# 2951 O
# --Skip: False
# 2952 CVHL
# --Skip: False
# 2953 RP
# --Skip: False
# 2954 RNWK
# --Skip: False
# 2955 RDI
# --Skip: False
# 2956 RCMT
# --Skip: False
# 2957 RICK
# --Skip: False
# 2958 RBCL
# --Skip: False
# 2959 ROLL
# --Skip: False
# 2960 RTX
# --Skip: False
# 2961 RYN
# --Skip: False
# 2962 RJF
# --Skip: False
# 2963 RAVN
# --Skip: False
# 2964 RAVE
# --Skip: False
# 2965 RTLLF
# --Skip: False
# 2966 REEMF
# --Skip: False
# 2967 RRC
# --Skip: False
# 2968 RANJY
# --Skip: False
# 2969 RANJF
# --Skip: False
# 2970 RWWI
# --Skip: False
# 2971 RAND
# --Skip: False
# 2972 RMSYF
# --Skip: False
# 2973 RMLRF
# --Skip: False
# 2974 RMBS
# --Skip: False
# 2975 RL
# --Skip: False
# 2976 RMNXF
# --Skip: False
# 2977 RAFLF
# --Skip: False
# 2978 RFLFF
# --Skip: False
# 2979 RDWR
# --Skip: False
# 2980 RDNT
# --Skip: False
# 2981 RDUFF
# --Skip: False
# 2982 RAIO
# --Skip: False
# 2983 RLGT
# --Skip: False
# 2984 RDN
# --Skip: False
# 2985 RDCM
# --Skip: False
# 2986 RADA
# --Skip: False
# 2987 RRD
# --Skip: False
# Done
